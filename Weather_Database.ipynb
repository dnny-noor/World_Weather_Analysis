# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Import the requests library.
import requests

#Import the API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | namibe
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | khor
# Processing Record 5 of Set 1 | namatanai
# Processing Record 6 of Set 1 | tete
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | batagay-alyta
# Processing Record 9 of Set 1 | chuy
# Processing Record 10 of Set 1 | mayor pablo lagerenza
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | mandalgovi
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 1 | harper
# Processing Record 16 of Set 1 | kamaishi
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 1 | mount isa
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | skibbereen
# Processing Record 25 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | yumbing
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | ostrovnoy
# Processing Record 33 of Set 1 | cayenne
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | salaga
# Processing Record 36 of Set 1 | lucapa
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | caravelas
# Processing Record 42 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | tromso
# Processing Record 46 of Set 1 | pitimbu
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | biak
# Processing Record 49 of Set 1 | awbari
# Processing Record 50 of Set 1 | matara
# Processing Record 1 of Set 2 | lodja
# Processing Record 2 of Set 2 | innisfail
# Processing Record 3 of Set 2 | bethel
# Processing Record 4 of Set 2 | taoudenni
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | butembo
# Processing Record 7 of Set 2 | marzuq
# Processing Record 8 of Set 2 | kaeo
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | porto novo
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | tshikapa
# Processing Record 15 of Set 2 | andenes
# Processing Record 16 of Set 2 | kununurra
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | matamoros
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | cabedelo
# Processing Record 21 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 2 | rawson
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | praxedis guerrero
# Processing Record 26 of Set 2 | zhoucheng
# Processing Record 27 of Set 2 | pafos
# Processing Record 28 of Set 2 | pangody
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | kalmunai
# Processing Record 31 of Set 2 | akyab
# Processing Record 32 of Set 2 | chokwe
# Processing Record 33 of Set 2 | jumla
# Processing Record 34 of Set 2 | alofi
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | hanyang
# Processing Record 37 of Set 2 | bystryy istok
# Processing Record 38 of Set 2 | hamilton
# Processing Record 39 of Set 2 | sitka
# Processing Record 40 of Set 2 | pimentel
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | miranda
# Processing Record 44 of Set 2 | ucluelet
# Processing Record 45 of Set 2 | sao filipe
# Processing Record 46 of Set 2 | dubenskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | horta
# Processing Record 48 of Set 2 | mitu
# Processing Record 49 of Set 2 | swellendam
# Processing Record 50 of Set 2 | dujuma
# City not found. Skipping...
# Processing Record 1 of Set 3 | alice springs
# Processing Record 2 of Set 3 | havelock
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | chapada dos guimaraes
# Processing Record 5 of Set 3 | mezen
# Processing Record 6 of Set 3 | yilan
# Processing Record 7 of Set 3 | tiarei
# Processing Record 8 of Set 3 | saint-joseph
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | anjangaon
# Processing Record 12 of Set 3 | saldanha
# Processing Record 13 of Set 3 | scarborough
# Processing Record 14 of Set 3 | panaba
# Processing Record 15 of Set 3 | sioux lookout
# Processing Record 16 of Set 3 | ovre ardal
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | tomatlan
# Processing Record 19 of Set 3 | turukhansk
# Processing Record 20 of Set 3 | gisborne
# Processing Record 21 of Set 3 | kargasok
# Processing Record 22 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 3 | saint george
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 3 | broome
# Processing Record 27 of Set 3 | orsha
# Processing Record 28 of Set 3 | lumphat
# Processing Record 29 of Set 3 | qaanaaq
# Processing Record 30 of Set 3 | douentza
# Processing Record 31 of Set 3 | sawtell
# Processing Record 32 of Set 3 | kirakira
# Processing Record 33 of Set 3 | avera
# Processing Record 34 of Set 3 | poya
# Processing Record 35 of Set 3 | wamba
# Processing Record 36 of Set 3 | vila franca do campo
# Processing Record 37 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | hermanus
# Processing Record 41 of Set 3 | coihaique
# Processing Record 42 of Set 3 | obo
# Processing Record 43 of Set 3 | qui nhon
# Processing Record 44 of Set 3 | shenjiamen
# Processing Record 45 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 3 | villa bruzual
# Processing Record 49 of Set 3 | tabou
# Processing Record 50 of Set 3 | leningradskiy
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | villa carlos paz
# Processing Record 3 of Set 4 | notodden
# Processing Record 4 of Set 4 | uglovskoye
# Processing Record 5 of Set 4 | boa vista
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | norman wells
# Processing Record 8 of Set 4 | ahlat
# Processing Record 9 of Set 4 | thompson
# Processing Record 10 of Set 4 | beringovskiy
# Processing Record 11 of Set 4 | jamestown
# Processing Record 12 of Set 4 | burnie
# Processing Record 13 of Set 4 | chunoyar
# Processing Record 14 of Set 4 | erin
# Processing Record 15 of Set 4 | vardo
# Processing Record 16 of Set 4 | guerrero negro
# Processing Record 17 of Set 4 | banswada
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | naze
# Processing Record 20 of Set 4 | alta floresta
# Processing Record 21 of Set 4 | belmonte
# Processing Record 22 of Set 4 | port alfred
# Processing Record 23 of Set 4 | saint-pierre
# Processing Record 24 of Set 4 | belle fourche
# Processing Record 25 of Set 4 | sorland
# Processing Record 26 of Set 4 | lebu
# Processing Record 27 of Set 4 | ignalina
# Processing Record 28 of Set 4 | victoria
# Processing Record 29 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 4 | gizo
# Processing Record 31 of Set 4 | san juan
# Processing Record 32 of Set 4 | kvareli
# Processing Record 33 of Set 4 | mangrol
# Processing Record 34 of Set 4 | ngunguru
# Processing Record 35 of Set 4 | kaitangata
# Processing Record 36 of Set 4 | itarema
# Processing Record 37 of Set 4 | haines junction
# Processing Record 38 of Set 4 | miracema do tocantins
# Processing Record 39 of Set 4 | ternate
# Processing Record 40 of Set 4 | sambava
# Processing Record 41 of Set 4 | provideniya
# Processing Record 42 of Set 4 | gat
# Processing Record 43 of Set 4 | mattawa
# Processing Record 44 of Set 4 | isangel
# Processing Record 45 of Set 4 | ponta do sol
# Processing Record 46 of Set 4 | morros
# Processing Record 47 of Set 4 | svetlogorsk
# Processing Record 48 of Set 4 | chenove
# Processing Record 49 of Set 4 | coquimbo
# Processing Record 50 of Set 4 | sur
# Processing Record 1 of Set 5 | port augusta
# Processing Record 2 of Set 5 | talnakh
# Processing Record 3 of Set 5 | fare
# Processing Record 4 of Set 5 | pisco
# Processing Record 5 of Set 5 | cabo san lucas
# Processing Record 6 of Set 5 | yar-sale
# Processing Record 7 of Set 5 | san pedro del pinatar
# Processing Record 8 of Set 5 | lorengau
# Processing Record 9 of Set 5 | airai
# Processing Record 10 of Set 5 | lompoc
# Processing Record 11 of Set 5 | tiksi
# Processing Record 12 of Set 5 | axim
# Processing Record 13 of Set 5 | arraial do cabo
# Processing Record 14 of Set 5 | los llanos de aridane
# Processing Record 15 of Set 5 | nijar
# Processing Record 16 of Set 5 | vershino-darasunskiy
# Processing Record 17 of Set 5 | san cristobal
# Processing Record 18 of Set 5 | sulangan
# Processing Record 19 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | codrington
# Processing Record 21 of Set 5 | bitung
# Processing Record 22 of Set 5 | barreirinha
# Processing Record 23 of Set 5 | vuktyl
# Processing Record 24 of Set 5 | saint-paul
# Processing Record 25 of Set 5 | alekseyevsk
# Processing Record 26 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 5 | lerwick
# Processing Record 28 of Set 5 | quatre cocos
# Processing Record 29 of Set 5 | bengkalis
# City not found. Skipping...
# Processing Record 30 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 31 of Set 5 | bonthe
# Processing Record 32 of Set 5 | avarua
# Processing Record 33 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 5 | fairbanks
# Processing Record 36 of Set 5 | the pas
# Processing Record 37 of Set 5 | bridlington
# Processing Record 38 of Set 5 | dudinka
# Processing Record 39 of Set 5 | pangkalanbuun
# Processing Record 40 of Set 5 | narsaq
# Processing Record 41 of Set 5 | deputatskiy
# Processing Record 42 of Set 5 | port hawkesbury
# Processing Record 43 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 5 | tuatapere
# Processing Record 45 of Set 5 | saint-francois
# Processing Record 46 of Set 5 | khatanga
# Processing Record 47 of Set 5 | miri
# Processing Record 48 of Set 5 | high level
# Processing Record 49 of Set 5 | sobolevo
# Processing Record 50 of Set 5 | mwinilunga
# Processing Record 1 of Set 6 | srednekolymsk
# Processing Record 2 of Set 6 | mahebourg
# Processing Record 3 of Set 6 | kruisfontein
# Processing Record 4 of Set 6 | lagoa
# Processing Record 5 of Set 6 | pangnirtung
# Processing Record 6 of Set 6 | limon
# Processing Record 7 of Set 6 | kavieng
# Processing Record 8 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 6 | ereymentau
# Processing Record 10 of Set 6 | kleck
# City not found. Skipping...
# Processing Record 11 of Set 6 | ajdabiya
# Processing Record 12 of Set 6 | arlit
# Processing Record 13 of Set 6 | salta
# Processing Record 14 of Set 6 | port hedland
# Processing Record 15 of Set 6 | touros
# Processing Record 16 of Set 6 | bengkulu
# Processing Record 17 of Set 6 | tome
# Processing Record 18 of Set 6 | constitucion
# Processing Record 19 of Set 6 | guadalupe y calvo
# Processing Record 20 of Set 6 | egvekinot
# Processing Record 21 of Set 6 | souillac
# Processing Record 22 of Set 6 | gondanglegi
# Processing Record 23 of Set 6 | chicama
# Processing Record 24 of Set 6 | aban
# Processing Record 25 of Set 6 | seydi
# Processing Record 26 of Set 6 | berkakit
# Processing Record 27 of Set 6 | pasir gudang
# Processing Record 28 of Set 6 | xitla
# City not found. Skipping...
# Processing Record 29 of Set 6 | berlevag
# Processing Record 30 of Set 6 | necochea
# Processing Record 31 of Set 6 | bambous virieux
# Processing Record 32 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 6 | mackenzie
# Processing Record 34 of Set 6 | colac
# Processing Record 35 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 6 | vostok
# Processing Record 37 of Set 6 | hoquiam
# Processing Record 38 of Set 6 | selkirk
# Processing Record 39 of Set 6 | thinadhoo
# Processing Record 40 of Set 6 | naliya
# Processing Record 41 of Set 6 | lexington
# Processing Record 42 of Set 6 | aykhal
# Processing Record 43 of Set 6 | newcastle
# Processing Record 44 of Set 6 | fort nelson
# Processing Record 45 of Set 6 | riyadh
# Processing Record 46 of Set 6 | tyumentsevo
# Processing Record 47 of Set 6 | cherskiy
# Processing Record 48 of Set 6 | mogadishu
# Processing Record 49 of Set 6 | asau
# Processing Record 50 of Set 6 | nelson bay
# Processing Record 1 of Set 7 | puerto carreno
# Processing Record 2 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 3 of Set 7 | warri
# Processing Record 4 of Set 7 | padang
# Processing Record 5 of Set 7 | shahr-e kord
# Processing Record 6 of Set 7 | camacha
# Processing Record 7 of Set 7 | sorong
# Processing Record 8 of Set 7 | carauari
# Processing Record 9 of Set 7 | port elizabeth
# Processing Record 10 of Set 7 | hobyo
# Processing Record 11 of Set 7 | salalah
# Processing Record 12 of Set 7 | galesong
# Processing Record 13 of Set 7 | libertador general san martin
# Processing Record 14 of Set 7 | savalou
# Processing Record 15 of Set 7 | gafanha da encarnacao
# Processing Record 16 of Set 7 | pevek
# Processing Record 17 of Set 7 | auki
# Processing Record 18 of Set 7 | tiznit
# Processing Record 19 of Set 7 | qinzhou
# Processing Record 20 of Set 7 | slonim
# Processing Record 21 of Set 7 | san jose
# Processing Record 22 of Set 7 | chifeng
# Processing Record 23 of Set 7 | morro bay
# Processing Record 24 of Set 7 | miraflores
# Processing Record 25 of Set 7 | kondinskoye
# Processing Record 26 of Set 7 | dingle
# Processing Record 27 of Set 7 | samarai
# Processing Record 28 of Set 7 | atambua
# Processing Record 29 of Set 7 | sao joao da barra
# Processing Record 30 of Set 7 | charters towers
# Processing Record 31 of Set 7 | grand gaube
# Processing Record 32 of Set 7 | gigmoto
# Processing Record 33 of Set 7 | nha trang
# Processing Record 34 of Set 7 | otautau
# Processing Record 35 of Set 7 | tocopilla
# Processing Record 36 of Set 7 | east london
# Processing Record 37 of Set 7 | manaure
# Processing Record 38 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 39 of Set 7 | prince rupert
# Processing Record 40 of Set 7 | gatesville
# Processing Record 41 of Set 7 | taltal
# Processing Record 42 of Set 7 | itaituba
# Processing Record 43 of Set 7 | lewisburg
# Processing Record 44 of Set 7 | coolum beach
# Processing Record 45 of Set 7 | dubovskoye
# Processing Record 46 of Set 7 | presque isle
# Processing Record 47 of Set 7 | iqaluit
# Processing Record 48 of Set 7 | huarmey
# Processing Record 49 of Set 7 | kot isa khan
# Processing Record 50 of Set 7 | malaut
# Processing Record 1 of Set 8 | pontalina
# Processing Record 2 of Set 8 | bronnoysund
# Processing Record 3 of Set 8 | vao
# Processing Record 4 of Set 8 | broken hill
# Processing Record 5 of Set 8 | sri aman
# Processing Record 6 of Set 8 | smithers
# Processing Record 7 of Set 8 | pochutla
# Processing Record 8 of Set 8 | octeville
# Processing Record 9 of Set 8 | cuiaba
# Processing Record 10 of Set 8 | comodoro rivadavia
# Processing Record 11 of Set 8 | guayaramerin
# Processing Record 12 of Set 8 | nampula
# Processing Record 13 of Set 8 | paita
# Processing Record 14 of Set 8 | esna
# Processing Record 15 of Set 8 | lima
# Processing Record 16 of Set 8 | margate
# Processing Record 17 of Set 8 | rio grande
# Processing Record 18 of Set 8 | shakawe
# Processing Record 19 of Set 8 | bac lieu
# Processing Record 20 of Set 8 | kuala sungai baru
# Processing Record 21 of Set 8 | dejen
# Processing Record 22 of Set 8 | katsuura
# Processing Record 23 of Set 8 | bud
# Processing Record 24 of Set 8 | taraza
# Processing Record 25 of Set 8 | turayf
# Processing Record 26 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 8 | port keats
# Processing Record 28 of Set 8 | mubi
# Processing Record 29 of Set 8 | okhotsk
# Processing Record 30 of Set 8 | pizarro
# Processing Record 31 of Set 8 | mujiayingzi
# Processing Record 32 of Set 8 | sidi bu zayd
# City not found. Skipping...
# Processing Record 33 of Set 8 | xai-xai
# Processing Record 34 of Set 8 | bozoum
# Processing Record 35 of Set 8 | mayumba
# Processing Record 36 of Set 8 | hofn
# Processing Record 37 of Set 8 | russell
# Processing Record 38 of Set 8 | tandil
# Processing Record 39 of Set 8 | nikolskoye
# Processing Record 40 of Set 8 | kahului
# Processing Record 41 of Set 8 | yelizovo
# Processing Record 42 of Set 8 | cleethorpes
# Processing Record 43 of Set 8 | bonavista
# Processing Record 44 of Set 8 | sisimiut
# Processing Record 45 of Set 8 | cotonou
# Processing Record 46 of Set 8 | pacific grove
# Processing Record 47 of Set 8 | soyo
# Processing Record 48 of Set 8 | solnechnyy
# Processing Record 49 of Set 8 | mnogovershinnyy
# Processing Record 50 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 1 of Set 9 | sola
# Processing Record 2 of Set 9 | hambantota
# Processing Record 3 of Set 9 | lazaro cardenas
# Processing Record 4 of Set 9 | grindavik
# Processing Record 5 of Set 9 | jipijapa
# Processing Record 6 of Set 9 | quelimane
# Processing Record 7 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 9 | ozernovskiy
# Processing Record 9 of Set 9 | tigre
# Processing Record 10 of Set 9 | kirovskiy
# Processing Record 11 of Set 9 | mecca
# Processing Record 12 of Set 9 | labrea
# Processing Record 13 of Set 9 | marataizes
# Processing Record 14 of Set 9 | sakrand
# Processing Record 15 of Set 9 | lata
# Processing Record 16 of Set 9 | batsfjord
# Processing Record 17 of Set 9 | sistranda
# Processing Record 18 of Set 9 | muzquiz
# City not found. Skipping...
# Processing Record 19 of Set 9 | gombong
# Processing Record 20 of Set 9 | ugoofaaru
# Processing Record 21 of Set 9 | belebey
# Processing Record 22 of Set 9 | hohhot
# Processing Record 23 of Set 9 | mayo
# Processing Record 24 of Set 9 | erenhot
# Processing Record 25 of Set 9 | santa isabel do rio negro
# Processing Record 26 of Set 9 | oranjemund
# Processing Record 27 of Set 9 | usinsk
# Processing Record 28 of Set 9 | basco
# Processing Record 29 of Set 9 | cartagena
# Processing Record 30 of Set 9 | hay river
# Processing Record 31 of Set 9 | awjilah
# Processing Record 32 of Set 9 | kremenchuk
# Processing Record 33 of Set 9 | sukhobezvodnoye
# Processing Record 34 of Set 9 | impfondo
# Processing Record 35 of Set 9 | sirjan
# Processing Record 36 of Set 9 | dezhou
# Processing Record 37 of Set 9 | plettenberg bay
# Processing Record 38 of Set 9 | karratha
# Processing Record 39 of Set 9 | piney green
# Processing Record 40 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 9 | baruun-urt
# Processing Record 42 of Set 9 | bogandinskiy
# Processing Record 43 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 9 | barcelos
# Processing Record 45 of Set 9 | ostersund
# Processing Record 46 of Set 9 | fiche
# Processing Record 47 of Set 9 | mombetsu
# Processing Record 48 of Set 9 | umba
# Processing Record 49 of Set 9 | thessalon
# Processing Record 50 of Set 9 | yerbogachen
# Processing Record 1 of Set 10 | coracao de jesus
# Processing Record 2 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 10 | baraboo
# Processing Record 4 of Set 10 | nyurba
# Processing Record 5 of Set 10 | merauke
# Processing Record 6 of Set 10 | roald
# Processing Record 7 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 10 | aklavik
# Processing Record 9 of Set 10 | asyut
# Processing Record 10 of Set 10 | balabac
# Processing Record 11 of Set 10 | warrington
# Processing Record 12 of Set 10 | zapolyarnyy
# Processing Record 13 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 14 of Set 10 | barentu
# Processing Record 15 of Set 10 | southbridge
# Processing Record 16 of Set 10 | nome
# Processing Record 17 of Set 10 | inuvik
# Processing Record 18 of Set 10 | fukue
# Processing Record 19 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 20 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 21 of Set 10 | guia de isora
# Processing Record 22 of Set 10 | mandan
# Processing Record 23 of Set 10 | amurzet
# Processing Record 24 of Set 10 | myitkyina
# Processing Record 25 of Set 10 | yarada
# Processing Record 26 of Set 10 | khani
# Processing Record 27 of Set 10 | port hardy
# Processing Record 28 of Set 10 | berea
# Processing Record 29 of Set 10 | ust-maya
# Processing Record 30 of Set 10 | savinka
# Processing Record 31 of Set 10 | bandarbeyla
# Processing Record 32 of Set 10 | shenkursk
# Processing Record 33 of Set 10 | half moon bay
# Processing Record 34 of Set 10 | tadine
# Processing Record 35 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 10 | viedma
# Processing Record 37 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 38 of Set 10 | houma
# Processing Record 39 of Set 10 | tautira
# Processing Record 40 of Set 10 | hakui
# Processing Record 41 of Set 10 | mitsamiouli
# Processing Record 42 of Set 10 | katobu
# Processing Record 43 of Set 10 | ladesti
# Processing Record 44 of Set 10 | mwingi
# Processing Record 45 of Set 10 | ginda
# Processing Record 46 of Set 10 | bairiki
# Processing Record 47 of Set 10 | salisbury
# Processing Record 48 of Set 10 | opuwo
# Processing Record 49 of Set 10 | nishihara
# Processing Record 50 of Set 10 | morondava
# Processing Record 1 of Set 11 | carutapera
# Processing Record 2 of Set 11 | montepuez
# Processing Record 3 of Set 11 | karaton
# Processing Record 4 of Set 11 | nicoya
# Processing Record 5 of Set 11 | domoni
# Processing Record 6 of Set 11 | okotoks
# Processing Record 7 of Set 11 | mahibadhoo
# Processing Record 8 of Set 11 | westerland
# Processing Record 9 of Set 11 | puerto del rosario
# Processing Record 10 of Set 11 | hirara
# Processing Record 11 of Set 11 | atbasar
# Processing Record 12 of Set 11 | bhawana
# Processing Record 13 of Set 11 | praia da vitoria
# Processing Record 14 of Set 11 | korla
# Processing Record 15 of Set 11 | takoradi
# Processing Record 16 of Set 11 | adrar
# Processing Record 17 of Set 11 | rawah
# Processing Record 18 of Set 11 | kodinsk
# Processing Record 19 of Set 11 | tevriz
# Processing Record 20 of Set 11 | flinders
# Processing Record 21 of Set 11 | dali
# Processing Record 22 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 23 of Set 11 | bhag
# Processing Record 24 of Set 11 | upernavik
# Processing Record 25 of Set 11 | rio blanco
# Processing Record 26 of Set 11 | manta
# Processing Record 27 of Set 11 | prachuap khiri khan
# Processing Record 28 of Set 11 | harigue
# City not found. Skipping...
# Processing Record 29 of Set 11 | gushikawa
# Processing Record 30 of Set 11 | tezu
# Processing Record 31 of Set 11 | saint anthony
# Processing Record 32 of Set 11 | maragogi
# Processing Record 33 of Set 11 | dosso
# Processing Record 34 of Set 11 | mutsu
# Processing Record 35 of Set 11 | neuquen
# Processing Record 36 of Set 11 | husavik
# Processing Record 37 of Set 11 | tessalit
# Processing Record 38 of Set 11 | teguldet
# Processing Record 39 of Set 11 | klaksvik
# Processing Record 40 of Set 11 | livingston
# Processing Record 41 of Set 11 | nanortalik
# Processing Record 42 of Set 11 | salina
# Processing Record 43 of Set 11 | bagotville
# Processing Record 44 of Set 11 | thaba-tseka
# Processing Record 45 of Set 11 | grants pass
# Processing Record 46 of Set 11 | la joya
# Processing Record 47 of Set 11 | waingapu
# Processing Record 48 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 49 of Set 11 | bellegarde-sur-valserine
# Processing Record 50 of Set 11 | vestmannaeyjar
# Processing Record 1 of Set 12 | qesarya
# Processing Record 2 of Set 12 | north bend
# Processing Record 3 of Set 12 | ozerki
# Processing Record 4 of Set 12 | chapais
# Processing Record 5 of Set 12 | eyrarbakki
# Processing Record 6 of Set 12 | wilmington
# Processing Record 7 of Set 12 | visnes
# Processing Record 8 of Set 12 | tunxi
# City not found. Skipping...
# Processing Record 9 of Set 12 | faya
# Processing Record 10 of Set 12 | homer
# Processing Record 11 of Set 12 | bolobo
# Processing Record 12 of Set 12 | bahir dar
# Processing Record 13 of Set 12 | tokat
# Processing Record 14 of Set 12 | kinkala
# Processing Record 15 of Set 12 | cayambe
# Processing Record 16 of Set 12 | vittorio veneto
# Processing Record 17 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 18 of Set 12 | jacksonville
# Processing Record 19 of Set 12 | diofior
# Processing Record 20 of Set 12 | san quintin
# Processing Record 21 of Set 12 | aquiraz
# Processing Record 22 of Set 12 | puerto suarez
# Processing Record 23 of Set 12 | seminole
# Processing Record 24 of Set 12 | shasta lake
# Processing Record 25 of Set 12 | elko
# Processing Record 26 of Set 12 | angra
# City not found. Skipping...
# Processing Record 27 of Set 12 | luangwa
# Processing Record 28 of Set 12 | ushtobe
# Processing Record 29 of Set 12 | nkhotakota
# Processing Record 30 of Set 12 | san martin
# Processing Record 31 of Set 12 | altoona
# Processing Record 32 of Set 12 | ybytimi
# City not found. Skipping...
# Processing Record 33 of Set 12 | madang
# Processing Record 34 of Set 12 | ahipara
# Processing Record 35 of Set 12 | nedjo
# Processing Record 36 of Set 12 | port macquarie
# Processing Record 37 of Set 12 | henties bay
# Processing Record 38 of Set 12 | cockburn town
# Processing Record 39 of Set 12 | amahai
# Processing Record 40 of Set 12 | bontang
# Processing Record 41 of Set 12 | ambon
# Processing Record 42 of Set 12 | linhai
# Processing Record 43 of Set 12 | bilma
# Processing Record 44 of Set 12 | rusape
# Processing Record 45 of Set 12 | najran
# Processing Record 46 of Set 12 | bukachacha
# Processing Record 47 of Set 12 | kabalo
# Processing Record 48 of Set 12 | meulaboh
# Processing Record 49 of Set 12 | houston
# Processing Record 50 of Set 12 | port-gentil
# Processing Record 1 of Set 13 | kamenz
# Processing Record 2 of Set 13 | pierre
# Processing Record 3 of Set 13 | ndele
# Processing Record 4 of Set 13 | esperance
# Processing Record 5 of Set 13 | vilcun
# Processing Record 6 of Set 13 | vohibinany
# Processing Record 7 of Set 13 | nanakuli
# Processing Record 8 of Set 13 | dongsheng
# Processing Record 9 of Set 13 | lagos
# Processing Record 10 of Set 13 | kalaleh
# Processing Record 11 of Set 13 | jalu
# Processing Record 12 of Set 13 | longyearbyen
# Processing Record 13 of Set 13 | san pedro
# Processing Record 14 of Set 13 | port-cartier
# Processing Record 15 of Set 13 | komsomolskiy
# Processing Record 16 of Set 13 | mount hagen
# Processing Record 17 of Set 13 | kenai
# Processing Record 18 of Set 13 | belaya gora
# Processing Record 19 of Set 13 | mantua
# Processing Record 20 of Set 13 | santa fe
# Processing Record 21 of Set 13 | sabang
# Processing Record 22 of Set 13 | tongliao
# Processing Record 23 of Set 13 | laguna
# Processing Record 24 of Set 13 | ntoum
# Processing Record 25 of Set 13 | kapit
# Processing Record 26 of Set 13 | tangier
# Processing Record 27 of Set 13 | kloulklubed
# Processing Record 28 of Set 13 | shu
# Processing Record 29 of Set 13 | luderitz
# Processing Record 30 of Set 13 | mount gambier
# Processing Record 31 of Set 13 | santa marta de tormes
# Processing Record 32 of Set 13 | te anau
# Processing Record 33 of Set 13 | acapulco
# Processing Record 34 of Set 13 | kupang
# Processing Record 35 of Set 13 | oktyabrskoye
# Processing Record 36 of Set 13 | ballina
# Processing Record 37 of Set 13 | qafsah
# City not found. Skipping...
# Processing Record 38 of Set 13 | sinnamary
# Processing Record 39 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 40 of Set 13 | parana
# Processing Record 41 of Set 13 | murmashi
# Processing Record 42 of Set 13 | maceio
# Processing Record 43 of Set 13 | cidreira
# Processing Record 44 of Set 13 | pauini
# Processing Record 45 of Set 13 | cortez
# Processing Record 46 of Set 13 | jimeta
# Processing Record 47 of Set 13 | rio grande da serra
# Processing Record 48 of Set 13 | neiafu
# Processing Record 49 of Set 13 | la ronge
# Processing Record 50 of Set 13 | olinda
# Processing Record 1 of Set 14 | aksu
# Processing Record 2 of Set 14 | ilulissat
# Processing Record 3 of Set 14 | morozovsk
# Processing Record 4 of Set 14 | marsh harbour
# Processing Record 5 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 14 | svetlyy
# Processing Record 7 of Set 14 | yelanskiy
# Processing Record 8 of Set 14 | shetpe
# Processing Record 9 of Set 14 | dunedin
# Processing Record 10 of Set 14 | dhidhdhoo
# Processing Record 11 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 14 | yatou
# Processing Record 13 of Set 14 | sakakah
# Processing Record 14 of Set 14 | jaguarari
# Processing Record 15 of Set 14 | canico
# Processing Record 16 of Set 14 | maryville
# Processing Record 17 of Set 14 | port lincoln
# Processing Record 18 of Set 14 | honiara
# Processing Record 19 of Set 14 | geraldton
# Processing Record 20 of Set 14 | toora-khem
# Processing Record 21 of Set 14 | alyangula
# Processing Record 22 of Set 14 | leshukonskoye
# Processing Record 23 of Set 14 | marabba
# Processing Record 24 of Set 14 | omboue
# Processing Record 25 of Set 14 | barra do garcas
# Processing Record 26 of Set 14 | verkhoyansk
# Processing Record 27 of Set 14 | mineros
# Processing Record 28 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 29 of Set 14 | bilibino
# Processing Record 30 of Set 14 | sena madureira
# Processing Record 31 of Set 14 | ruston
# Processing Record 32 of Set 14 | shingu
# Processing Record 33 of Set 14 | poum
# Processing Record 34 of Set 14 | golden
# Processing Record 35 of Set 14 | hasaki
# Processing Record 36 of Set 14 | nata
# Processing Record 37 of Set 14 | minab
# Processing Record 38 of Set 14 | kismayo
# Processing Record 39 of Set 14 | antofagasta
# Processing Record 40 of Set 14 | la palma
# Processing Record 41 of Set 14 | ossora
# Processing Record 42 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 43 of Set 14 | burica
# City not found. Skipping...
# Processing Record 44 of Set 14 | pingdu
# Processing Record 45 of Set 14 | saint-augustin
# Processing Record 46 of Set 14 | quarai
# Processing Record 47 of Set 14 | karakose
# City not found. Skipping...
# Processing Record 48 of Set 14 | ancud
# Processing Record 49 of Set 14 | santa rita
# Processing Record 50 of Set 14 | voyvozh
# Processing Record 1 of Set 15 | mushie
# Processing Record 2 of Set 15 | yokadouma
# Processing Record 3 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 15 | lesmahagow
# Processing Record 5 of Set 15 | zhezkazgan
# Processing Record 6 of Set 15 | verkhnevilyuysk
# Processing Record 7 of Set 15 | anchorage
# Processing Record 8 of Set 15 | gunjur
# Processing Record 9 of Set 15 | inongo
# Processing Record 10 of Set 15 | oistins
# Processing Record 11 of Set 15 | petukhovo
# Processing Record 12 of Set 15 | zhigansk
# Processing Record 13 of Set 15 | kyra
# Processing Record 14 of Set 15 | andros town
# Processing Record 15 of Set 15 | zlobin
# Processing Record 16 of Set 15 | novosergiyevka
# Processing Record 17 of Set 15 | semey
# Processing Record 18 of Set 15 | okha
# Processing Record 19 of Set 15 | san carlos de bariloche
# Processing Record 20 of Set 15 | kieta
# Processing Record 21 of Set 15 | linfen
# Processing Record 22 of Set 15 | udachnyy
# Processing Record 23 of Set 15 | birjand
# Processing Record 24 of Set 15 | kayunga
# Processing Record 25 of Set 15 | college
# Processing Record 26 of Set 15 | drayton valley
# Processing Record 27 of Set 15 | madona
# Processing Record 28 of Set 15 | nemuro
# Processing Record 29 of Set 15 | george
# Processing Record 30 of Set 15 | gua musang
# Processing Record 31 of Set 15 | marawi
# Processing Record 32 of Set 15 | tazovskiy
# Processing Record 33 of Set 15 | khamgaon
# Processing Record 34 of Set 15 | tashara
# Processing Record 35 of Set 15 | asheboro
# Processing Record 36 of Set 15 | slave lake
# Processing Record 37 of Set 15 | bubaque
# Processing Record 38 of Set 15 | hibbing
# Processing Record 39 of Set 15 | kunya
# Processing Record 40 of Set 15 | tanete
# Processing Record 41 of Set 15 | isabela
# Processing Record 42 of Set 15 | luganville
# Processing Record 43 of Set 15 | birin
# Processing Record 44 of Set 15 | limbang
# Processing Record 45 of Set 15 | the valley
# Processing Record 46 of Set 15 | atlantic city
# Processing Record 47 of Set 15 | makakilo city
# Processing Record 48 of Set 15 | manuk mangkaw
# Processing Record 49 of Set 15 | san patricio
# Processing Record 50 of Set 15 | kondol
# Processing Record 1 of Set 16 | chistogorskiy
# Processing Record 2 of Set 16 | helong
# Processing Record 3 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 4 of Set 16 | arman
# Processing Record 5 of Set 16 | santiago
# Processing Record 6 of Set 16 | tara
# Processing Record 7 of Set 16 | taraz
# Processing Record 8 of Set 16 | huanren
# Processing Record 9 of Set 16 | angoche
# Processing Record 10 of Set 16 | fort william
# Processing Record 11 of Set 16 | suchiate
# Processing Record 12 of Set 16 | union city
# Processing Record 13 of Set 16 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 16 | popondetta
# Processing Record 15 of Set 16 | mao
# Processing Record 16 of Set 16 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 16 | tucuman
# Processing Record 18 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 16 | cam pha
# City not found. Skipping...
# Processing Record 20 of Set 16 | xining
# Processing Record 21 of Set 16 | kharp
# Processing Record 22 of Set 16 | clinton
# Processing Record 23 of Set 16 | fukuma
# Processing Record 24 of Set 16 | malanje
# Processing Record 25 of Set 16 | lar
# Processing Record 26 of Set 16 | polovinnoye
# Processing Record 27 of Set 16 | megion
# Processing Record 28 of Set 16 | kushmurun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 710

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Namibe      AO -15.1961   12.1522     72.79        75
# 1              Busselton      AU -33.6500  115.3333     87.01        44
# 2           Punta Arenas      CL -53.1500  -70.9167     48.20        71
# 3                   Khor      RU  47.8861  134.9464    -13.38        85
# 4              Namatanai      PG  -3.6667  152.4333     84.49        66
# 5                   Tete      MZ -16.1564   33.5867     73.35        94
# 6                 Atuona      PF  -9.8000 -139.0333     79.07        76
# 7          Batagay-Alyta      RU  67.8006  130.4114    -33.41        80
# 8                   Chuy      UY -33.6971  -53.4616     68.34        93
# 9  Mayor Pablo Lagerenza      PY -19.9309  -60.7718     82.33        63
#
#    Cloudiness  Wind Speed Current Description
# 0          97        5.08     overcast clouds
# 1           0        1.99           clear sky
# 2           0       17.27           clear sky
# 3           0       11.72           clear sky
# 4         100       13.27     overcast clouds
# 5          90        3.22     overcast clouds
# 6          84       17.18       broken clouds
# 7          89        2.24     overcast clouds
# 8         100       15.59          light rain
# 9          19        9.86          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
